# %%
# !pip install -q snscrape

# %%
import os
import pandas as pd
from datetime import date
import re
import nltk
import string
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\ashwin
# [nltk_data]     s\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\ashwin
# [nltk_data]     s\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\ashwin
# [nltk_data]     s\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\ashwin
# [nltk_data]     s\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
today=date.today()
end_date=today
print(end_date)
search_term="ukraine OR russia OR ukraine war OR russia war OR russia ukraine war"
max_results = 1000
extracted_tweets = "snscrape --format '{content!r}'"+ f" --max-results {max_results} --since {end_date} twitter-search '{search_term} lang:en ' > scraped-tweets.txt"
os.system(extracted_tweets)
# Out:
# 2023-04-26
# 2

# %%
df = pd.read_csv("C:/Users/ashwin s/Desktop/Ashwin/Project/Ukraine Russia NLP/ukarine-russia-war-tweet-analysis-using-NLP-main/scrape-tweets.txt", delimiter="\t", header=None)
df.head(10)
tweets=df.to_numpy()
print(tweets.shape)
tweets= tweets.reshape(-1)
print(tweets.shape)
# Out:
# (1000, 1)
# (1000,)

# %%
df
# Out:
#                                                      0
# 0    @saxena_puru all sectors will go through rinse...
# 1    Russia's army may not recover from the Ukraine...
# 2    Ukraine war latest: Russian leader of Kherson ...
# 3    Russia's army may not recover from the Ukraine...
# 4    'Ukraine war latest: Russian leader of Kherson...
# ..                                                 ...
# 995  'Ukraine War Footage - DIRECT HIT of Drone-Dro...
# 996  '@Kebi13148864 @joeljacob202 8000km is seven y...
# 997  '@MAbdullahGul @nadeemmalik Do you observe how...
# 998  '@cityafreaks If the Ukraine war ends soon I c...
# 999  'A Tories stock answer is Ukraine war, no wond...
#
# [1000 rows x 1 columns]

# %%
stemmer=WordNetLemmatizer()
def cleaner(ndarr):
  tweets=ndarr.copy()
  pattern=r'(?i)\b((?:[a-z][\w-]+:(?:/{1,3}|[a-z0-9%])|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:\'".,<>?«»“”‘’]))';
  for i in range(len(tweets)):
      tweet=tweets[i]
      tweet=re.sub(pattern," ",str(tweet)) #urls
      tweet=re.sub(r"\W"," ",tweet) #special chars
      tweet=re.sub(re.escape(string.punctuation),"",tweet) #punctuation
      tweet=re.sub(r"\s+[a-zA-Z]\s+"," ",tweet) #remove single char
      tweet=re.sub(r"\^[a-zA-Z]\s+"," ",tweet)  #remove single char from start and end
      tweet=re.sub(r"\s+"," ",tweet,flags=re.I) #remove extra spaces
      tweet=tweet.lower()
      tweet=tweet.split()
      tweet=[stemmer.lemmatize(word) for word in tweet]
      tweet=[word for word in tweet if word not in stopwords.words("english")]

      tweet=" ".join(tweet)
      tweets[i]=tweet
  return tweets

# %%
tweets=cleaner(tweets)
tweets=cleaner(tweets)
print(tweets[:5])
df["Tweets"]=tweets
df["Tweets"].drop_duplicates(inplace = True)
df.to_csv("clean-tweets.csv",index=False)
# Out:
# ['saxena_puru sector go rinse cycle ukraine war eu going deep cold winter xle high lock profit protection'
#  'russia army may recover ukraine war putin ha lost half tank find difficult rebuild pentagon say xa0 nvia'
#  'ukraine war latest russian leader kherson killed telegraph news'
#  'russia army may recover ukraine war putin ha lost half tank find difficult rebuild pentagon say xa0 nvia'
#  'ukraine war latest russian leader kherson killed xa0telegraph']

# %%
from itertools import chain
keywords=[x.split() for x in tweets]
keywords = list(chain.from_iterable(keywords))
keywords
# Out:
# ['saxena_puru',
#  'sector',
#  'go',
#  'rinse',
#  'cycle',
#  'ukraine',
#  'war',
#  'eu',
#  'going',
#  'deep',
#  'cold',
#  'winter',
#  'xle',
#  'high',
#  'lock',
#  'profit',
#  'protection',
#  'russia',
#  'army',
#  'may',
#  'recover',
#  'ukraine',
#  'war',
#  'putin',
#  'ha',
#  'lost',
#  'half',
#  'tank',
#  'find',
#  'difficult',
#  'rebuild',
#  'pentagon',
#  'say',
#  'xa0',
#  'nvia',
#  'ukraine',
#  'war',
#  'latest',
#  'russian',
#  'leader',
#  'kherson',
#  'killed',
#  'telegraph',
#  'news',
#  'russia',
#  'army',
#  'may',
#  'recover',
#  'ukraine',
#  'war',
#  'putin',
#  'ha',
#  'lost',
#  'half',
#  'tank',
#  'find',
#  'difficult',
#  'rebuild',
#  'pentagon',
#  'say',
#  'xa0',
#  'nvia',
#  'ukraine',
#  'war',
#  'latest',
#  'russian',
#  'leader',
#  'kherson',
#  'killed',
#  'xa0telegraph',
#  'british',
#  'intelligence',
#  'update',
#  'ukraine',
#  'war',
#  'today',
#  'nov',
#  '9',
#  'latest',
#  'war',
#  'map',
#  'kherson',
#  'luhansk',
#  'kharkiv',
#  'front',
#  'kambaimagic',
#  '7',
#  'year',
#  'sir',
#  'ncost',
#  'food',
#  'rising',
#  'today',
#  'due',
#  'ukraine',
#  'war',
#  'dailyloud',
#  'long',
#  'ukraine',
#  'war',
#  'go',
#  'never',
#  'released',
#  'would',
#  'russia',
#  'release',
#  'american',
#  'prisoner',
#  'sending',
#  'billion',
#  'ukraine',
#  'fight',
#  'russia',
#  'pawn',
#  'global',
#  'chess',
#  'game',
#  'senategop',
#  'inflation',
#  'worldwide',
#  'problem',
#  'caused',
#  'coronavirus',
#  'pandemic',
#  'russia',
#  'ukraine',
#  'war',
#  'nand',
#  'corporate',
#  'greed',
#  'majority',
#  'price',
#  'increase',
#  'go',
#  'corporate',
#  'profit',
#  'inflation',
#  'ukraine',
#  'drone',
#  'drop',
#  'bomb',
#  'right',
#  'next',
#  'russian',
#  'troop',
#  'head',
#  'brutal',
#  'hit',
#  'ukraine',
#  'ukrainewar',
#  'russia',
#  'canada',
#  'electionday',
#  'unitedstates',
#  'kherson',
#  'ukrainerussiawar',
#  'jensstoltenberg',
#  'erna_solberg',
#  'presidentccp1',
#  'ukraine',
#  'war',
#  'becouse',
#  'corona',
#  'see',
#  'pattern',
#  'anumal',
#  'bat',
#  'make',
#  'eachother',
#  'hungry',
#  'half',
#  'die',
#  'stopped',
#  'flying',
#  'corona',
#  'suddenly',
#  'appear',
#  'lucky',
#  'feed',
#  'rest',
#  'ukrainian',
#  'force',
#  'liberated',
#  'long',
#  'contested',
#  'strategically',
#  'important',
#  'village',
#  'snihurivka',
#  'bashtanka',
#  'raion',
#  'mykolaiv',
#  'oblast',
#  'open',
#  'way',
#  'advance',
#  'kherson',
#  'ukraine',
#  'war',
#  'china',
#  'lone',
#  'bright',
#  'spot',
#  'world',
#  'rich',
#  'population',
#  'shrink',
#  'amid',
#  'slump',
#  'stock',
#  'market',
#  'caused',
#  'russia',
#  'ukraine',
#  'war',
#  'russia',
#  'ukraine',
#  'war',
#  'list',
#  'key',
#  'event',
#  'day',
#  'xa0259',
#  'ukraine',
#  'war',
#  'latest',
#  'russian',
#  'leader',
#  'kherson',
#  'killed',
#  'tell',
#  'abut',
#  'wmd',
#  'langenstein',
#  'ha',
#  'monaco',
#  'plan',
#  'invade',
#  'chile',
#  'foukkers',
#  'something',
#  'else',
#  'wait',
#  'ru',
#  'unleashes',
#  'stalingrad',
#  'like',
#  'offensive',
#  'soon',
#  'may',
#  'stop',
#  'till',
#  'hq',
#  'basketball',
#  'player',
#  'brittney',
#  'griner',
#  'moved',
#  'russian',
#  'penal',
#  'colony',
#  'russia',
#  'ukraine',
#  'war',
#  'xa0news',
#  'russia',
#  'ukraine',
#  'war',
#  'list',
#  'key',
#  'event',
#  'day',
#  'xa0259',
#  'diorgotem',
#  'dailyloud',
#  'russo',
#  'ukraine',
#  'war',
#  'happening',
#  'would',
#  'freed',
#  'completely',
#  'political',
#  'statement',
#  'u',
#  'russia',
#  'ukraine',
#  'war',
#  'list',
#  'key',
#  'event',
#  'day',
#  'xa0259',
#  'dropping',
#  'grenade',
#  'ukrainian',
#  'militant',
#  'ukraine',
#  'ukrainerussianwar',
#  'ukrainewar',
#  'russia',
#  'nato',
#  'usa',
#  'selenskyj',
#  'greatbritain',
#  'eu',
#  'kherson',
#  'kharkiv',
#  'bakhmut',
#  'russia',
#  'ukraine',
#  'war',
#  'list',
#  'key',
#  'event',
#  'day',
#  'xa0259',
#  'russia',
#  'ukraine',
#  'war',
#  'member',
#  'ukraine',
#  'state',
#  'emergency',
#  'service',
#  'inspect',
#  'dismantled',
#  'monument',
#  'dedicated',
#  'soviet',
#  'liberator',
#  'following',
#  'decision',
#  'local',
#  'authority',
#  'uzhhorod',
#  'ukraine',
#  'mpeinovichnjp',
#  'think',
#  'average',
#  'person',
#  'give',
#  'crap',
#  'sending',
#  'money',
#  'ukraine',
#  'war',
#  'people',
#  'overwhelmingly',
#  'think',
#  'russia',
#  'line',
#  'invading',
#  'ukraine',
#  'certainly',
#  'people',
#  'tired',
#  'throwing',
#  'money',
#  'around',
#  'world',
#  'one',
#  'case',
#  'accept',
#  'fight',
#  'pavlovka',
#  'ndestruction',
#  'american',
#  'mci',
#  'maxxpro',
#  'ukraine',
#  'ukrainerussianwar',
#  'ukrainewar',
#  'russia',
#  'nato',
#  'usa',
#  'selenskyj',
#  'greatbritain',
#  'eu',
#  'kherson',
#  'kharkiv',
#  'bakhmut',
#  'weird',
#  'ukraine',
#  'war',
#  'drone',
#  'footage',
#  'russian',
#  'soldier',
#  'run',
#  'drone',
#  'drop',
#  'grenade',
#  'position',
#  'canada',
#  'electionday',
#  'unitedstates',
#  'kherson',
#  'ukrainerussiawar',
#  'chicago1ray',
#  'hillaryclinton',
#  'joebiden',
#  'wa',
#  'ukraine',
#  'war',
#  'russian',
#  'manipulation',
#  'gas',
#  'price',
#  'trump',
#  'time',
#  'leave',
#  'economics',
#  'actually',
#  'understand',
#  'subject',
#  'kind',
#  'sir',
#  'call',
#  'youth',
#  'throughout',
#  'world',
#  'build',
#  'mass',
#  'movement',
#  'stop',
#  'ukraine',
#  'war',
#  'exactly',
#  'sean',
#  'penn',
#  'oscar',
#  'going',
#  'help',
#  'russia',
#  'ukraine',
#  'war',
#  'going',
#  'work',
#  'send',
#  '400m',
#  'backstroke',
#  'swimming',
#  'badge',
#  'help',
#  'fight',
#  'good',
#  'fight',
#  'russian',
#  'blow',
#  'bridge',
#  'right',
#  'bank',
#  'kherson',
#  'oblast',
#  'ukraine',
#  'war',
#  'new',
#  'voice',
#  'ukraine',
#  'russia',
#  'ukraine',
#  'war',
#  'live',
#  'russian',
#  'installed',
#  'kherson',
#  'official',
#  'dy',
#  'car',
#  'crash',
#  'report',
#  'say',
#  'crimea',
#  'bridge',
#  'may',
#  'repaired',
#  'year',
#  'driving',
#  'news',
#  'confirmed',
#  'kherson',
#  'collaborationist',
#  'official',
#  'kirill',
#  'stremousov',
#  'killed',
#  'ukraine',
#  'ukrainewar',
#  'russia',
#  'russiaukrainewar',
#  'russianwarcrimes',
#  'watch',
#  'lied',
#  'ukraine',
#  'war',
#  'youtube',
#  'grenade',
#  'drop',
#  'century',
#  'analyzing',
#  '5',
#  'drone',
#  'kill',
#  'ukraine',
#  'war',
#  'canada',
#  'electionday',
#  'unitedstates',
#  'kherson',
#  'ukrainerussiawar',
#  'pti_news',
#  'might',
#  'also',
#  'plan',
#  'ukraine',
#  'war',
#  'kaitlinlwebb',
#  'gabihaters',
#  'aaliuk',
#  'runews',
#  'suspect',
#  'russian',
#  'bot',
#  'nleave',
#  'evil',
#  'witch',
#  'join',
#  'putin',
#  'supporter',
#  'misinformation',
#  'international',
#  'court',
#  'hague',
#  'nanyone',
#  'try',
#  'justify',
#  'russia',
#  'illegal',
#  'invasion',
#  'ukraine',
#  'war',
#  'crime',
#  'rape',
#  'torture',
#  'murder',
#  'child',
#  'trafficking',
#  'criminal',
#  '2022',
#  'midterm',
#  'election',
#  'nthere',
#  'focus',
#  'shift',
#  'russia',
#  'onto',
#  'china',
#  'make',
#  '2023',
#  'great',
#  'war',
#  'likely',
#  'happen',
#  'putin',
#  '2022',
#  'ukraine',
#  'war',
#  'end',
#  'earlier',
#  'republican',
#  'take',
#  'control',
#  'house',
#  'ukraine',
#  'war',
#  'control',
#  'kherson',
#  'important',
#  'ukraine',
#  'ukrainerussiawar',
#  'basketball',
#  'player',
#  'brittney',
#  'griner',
#  'moved',
#  'russian',
#  'penal',
#  'colony',
#  'russia',
#  'ukraine',
#  'war',
#  'xa0news',
#  'china',
#  'super',
#  'rich',
#  'saw',
#  'wealth',
#  'fall',
#  'largest',
#  'amount',
#  'two',
#  'decade',
#  'russia',
#  'ukraine',
#  'war',
#  'beijing',
#  'zero',
#  'covid',
#  'measure',
#  'falling',
#  'local',
#  'stock',
#  'market',
#  'pummelled',
#  'fortune',
#  'russia',
#  'army',
#  'may',
#  'never',
#  'recover',
#  'ukraine',
#  'war',
#  'pentagon',
#  'say',
#  'via',
#  'mailonline',
#  'greenneighbour',
#  'omgwai',
#  'michaelemann',
#  'let',
#  'talk',
#  'ukraine',
#  'war',
#  'avoiding',
#  'nuclear',
#  'war',
#  'good',
#  'idea',
#  'didnt',
#  'lobby',
#  'nuclear',
#  'disarment',
#  'side',
#  'authoritarian',
#  'regime',
#  'agenda',
#  'approve',
#  'tweet',
#  'give',
#  'inch',
#  'go',
#  'mile',
#  'appeasement',
#  'failed',
#  'wwii',
#  'russia',
#  'ukraine',
#  'war',
#  'drone',
#  'footage',
#  'ukrainian',
#  'drone',
#  'drop',
#  'grenade',
#  'group',
#  'russian',
#  'soldier',
#  'canada',
#  'electionday',
#  'unitedstates',
#  'kherson',
#  'ukraine',
#  'russia',
#  'ukraine',
#  'war',
#  'video',
#  '11',
#  '9',
#  '2022',
#  'nmore',
#  'twitter',
#  'ukraine',
#  'news',
#  'link',
#  '9',
#  '9',
#  'n17',
#  'europe',
#  'ha',
#  'extremely',
#  'cold',
#  'winter',
#  'screwed',
#  'gas',
#  'storage',
#  'last',
#  'issue',
#  'look',
#  'forward',
#  'next',
#  '2',
#  '3',
#  'year',
#  'russia',
#  'ukraine',
#  'war',
#  'end',
#  'n18',
#  'fed',
#  'continue',
#  'tightening',
#  'amp',
#  'borrowing',
#  'cost',
#  'vastly',
#  'increase',
#  'nenjoy',
#  'russia',
#  'ukraine',
#  'war',
#  'video',
#  '11',
#  '9',
#  '2022',
#  'nfrench',
#  'fighter',
#  'international',
#  'legion',
#  'front',
#  'line',
#  'ukraine',
#  'nmore',
#  'twitter',
#  'news',
#  'link',
#  'bbc',
#  'context',
#  'ukraine',
#  'war',
#  'nato',
#  'pushing',
#  'russia',
#  'provoke',
#  'conflict',
#  'fail',
#  'miserably',
#  'ukraine',
#  'russia',
#  'war',
#  'video',
#  '11',
#  '9',
#  '2022',
#  'nweekdays',
#  'soldier',
#  'kastus',
#  'kalinouski',
#  'regiment',
#  'waiting',
#  'katsap',
#  'armor',
#  'nmore',
#  'breaking',
#  'news',
#  'link',
#  'twitter',
#  'russia',
#  'ukraine',
#  'war',
#  'hidden',
#  'actually',
#  'open',
#  '3rd',
#  'world',
#  'war',
#  '09',
#  '11',
#  '2022',
#  'russia',
#  'bring',
#  'enemy',
#  'knee',
#  'winner',
#  '3rd',
#  'world',
#  'war',
#  'russia',
#  'alone',
#  'ukraine',
#  'defeated',
#  'america',
#  'germany',
#  'france',
#  'england',
#  'eu',
#  'slave',
#  'state',
#  'ukraine',
#  'russia',
#  'war',
#  'video',
#  '11',
#  '9',
#  '2022',
#  'nmore',
#  'breaking',
#  'news',
#  'link',
#  'twitter',
#  'russia',
#  'ukraine',
#  'war',
#  'video',
#  '11',
#  '9',
#  '2022',
#  'nanomalous',
#  'footage',
#  'somewhere',
#  'europe',
#  'location',
#  'given',
#  'could',
#  'possibly',
#  'ukraine',
#  'n________',
#  'nmore',
#  'twitter',
#  'hot',
#  'news',
#  'link',
#  'republican',
#  'deserve',
#  'win',
#  'running',
#  'covid',
#  'conspiracy',
#  'election',
#  'fraud',
#  'compelling',
#  'people',
#  'actually',
#  'run',
#  'crime',
#  'ukraine',
#  'war',
#  'except',
#  'timidly',
#  'end',
#  'trumpist',
#  'candidate',
#  'touch',
#  'either',
#  'immigration',
#  'wa',
#  'barely',
#  'mentioned',
#  'russia',
#  'ukraine',
#  'war',
#  'video',
#  '11',
#  '9',
#  '2022',
#  'ntoday',
#  'russian',
#  'fleeing',
#  'position',
#  'kherson',
#  'region',
#  'military',
#  'seized',
#  'truck',
#  'nmore',
#  'war',
#  'news',
#  'link',
#  'twitter',
#  '_',
#  'caliban',
#  'news',
#  'feed',
#  '_',
#  'nukraine',
#  'war',
#  'moscow',
#  'installed',
#  'deputy',
#  'governor',
#  'kherson',
#  'died',
#  'car',
#  'crash',
#  'russia',
#  'ukraine',
#  'war',
#  'stay',
#  'russian',
#  'installed',
#  'kherson',
#  'official',
#  'dy',
#  'car',
#  'crash',
#  'report',
#  'say',
#  'crimea',
#  'bridge',
#  'may',
#  'repaired',
#  'year',
#  'ukraine',
#  'amp',
#  'latest',
#  'xa0news',
#  'russia',
#  'ukraine',
#  'war',
#  'stay',
#  'russian',
#  'installed',
#  'kherson',
#  'official',
#  'dy',
#  'car',
#  'crash',
#  'report',
#  'say',
#  'crimea',
#  'bridge',
#  'may',
#  'repaired',
#  'year',
#  'ukraine',
#  'amp',
#  'latest',
#  'xa0news',
#  'basketball',
#  'player',
#  'brittney',
#  'griner',
#  'moved',
#  'russian',
#  'penal',
#  'colony',
#  'russia',
#  'ukraine',
#  'war',
#  'xa0news',
#  'ukraine',
#  'russia',
#  'war',
#  'video',
#  '11',
#  '9',
#  '2022',
#  'nmarinka',
#  'donetsk',
#  'region',
#  'nmore',
#  'breaking',
#  'news',
#  'link',
#  'twitter',
#  'salem',
#  'al',
#  'ketbi',
#  'uae',
#  'mediates',
#  'ukraine',
#  'war',
#  'different',
#  'tact',
#  'age',
#  'take',
#  'people',
#  'ukraine',
#  'war',
#  'catch',
#  'russian',
#  'elite',
#  'russia',
#  'ukraine',
#  'war',
#  'video',
#  '11',
#  '9',
#  '2022',
#  'nukrainian',
#  'military',
#  'knocked',
#  'russian',
#  'tank',
#  'donetsk',
#  'region',
#  'nmore',
#  'ukraine',
#  'news',
#  'link',
#  ...]

# %%
from nltk.probability import FreqDist
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
#import matplotlib.pyplot as plt
import seaborn as sns

df2 = pd.DataFrame(keywords)
df2 = df2[0].value_counts()

freq = FreqDist()
for words in df2:
    freq[words] += 1

print(freq)

df2 = df2[:30,]
plt.figure(figsize=(10,5))
sns.barplot(df2.values, df2.index, alpha=0.8)
plt.title('Top Words Overall')
plt.ylabel('Word from Tweet', fontsize=12)
plt.xlabel('Count of Words', fontsize=12)
plt.show()
# Out:
# <FreqDist with 66 samples and 4192 outcomes>
# C:\Users\ashwin s\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from textblob import TextBlob
def classfier(x):
  if(x>0):
    return "Positive"
  elif (x==0):
    return "Neutral"
  else:
    return "Negative"
df["polarity"]=df["Tweets"].apply(lambda x :TextBlob(x).sentiment[0])
df["Subjectivity"]=df["Tweets"].apply(lambda x :TextBlob(x).sentiment[1])
df["Lenght"]=df["Tweets"].apply(lambda x : len(x.split()))
# df["class"]=df["polarity"].apply(lambda x:  "POSITIVE" if x > 0 else "NEGATIVE" )
df["class"]=df["polarity"].apply(lambda x:  classfier(x))

# %%
df.head(20)
# Out:
#                                                     0  \
# 0   @saxena_puru all sectors will go through rinse...
# 1   Russia's army may not recover from the Ukraine...
# 2   Ukraine war latest: Russian leader of Kherson ...
# 3   Russia's army may not recover from the Ukraine...
# 4   'Ukraine war latest: Russian leader of Kherson...
# 5   'British Intelligence update on Ukraine war as...
# 6   '@kambaimagic 7 years sir.\n\nCost of food is ...
# 7   '@DailyLoud As long as the Ukraine war goes on...
# 8   @SenateGOP Inflation is a worldwide problem.  ...
# 9   'Ukraine Drone Drops Bomb Right Next To Russia...
# 10  '@jensstoltenberg @erna_solberg @PresidentCCP1...
# 11  'Ukrainian forces liberated the long contested...
# 12  'China is lone bright spot as world’s rich pop...
# 13  'Russia-Ukraine War: List of Key Events, Day\x...
# 14  Ukraine war latest: Russian leader of Kherson ...
# 15  'Basketball player Brittney Griner moved to Ru...
# 16  'Russia-Ukraine War: List of Key Events, Day\x...
# 17  '@DiorGotEm @DailyLoud If the Russo Ukraine wa...
# 18  'Russia-Ukraine War: List of Key Events, Day\x...
# 19  '🇷🇺🇺🇦 Dropping a grenade on Ukrainian militant...
#
#                                                Tweets  polarity  Subjectivity  \
# 0   saxena_puru sector go rinse cycle ukraine war ... -0.146667      0.646667
# 1   russia army may recover ukraine war putin ha l... -0.333333      0.583333
# 2   ukraine war latest russian leader kherson kill...  0.100000      0.300000
# 3   russia army may recover ukraine war putin ha l... -0.333333      0.583333
# 4   ukraine war latest russian leader kherson kill...  0.100000      0.300000
# 5   british intelligence update ukraine war today ...  0.250000      0.450000
# 6   kambaimagic 7 year sir ncost food rising today... -0.125000      0.375000
# 7   dailyloud long ukraine war go never released w... -0.112500      0.200000
# 8   senategop inflation worldwide problem caused c...  0.000000      0.000000
# 9   ukraine drone drop bomb right next russian tro... -0.147321      0.383929
# 10  jensstoltenberg erna_solberg presidentccp1 ukr...  0.055556      0.500000
# 11  ukrainian force liberated long contested strat...  0.116667      0.633333
# 12  china lone bright spot world rich population s...  0.537500      0.775000
# 13       russia ukraine war list key event day xa0259  0.000000      1.000000
# 14  ukraine war latest russian leader kherson kill...  0.100000      0.300000
# 15  basketball player brittney griner moved russia...  0.000000      0.000000
# 16       russia ukraine war list key event day xa0259  0.000000      1.000000
# 17  diorgotem dailyloud russo ukraine war happenin...  0.000000      0.100000
# 18       russia ukraine war list key event day xa0259  0.000000      1.000000
# 19  dropping grenade ukrainian militant ukraine uk...  0.000000      0.000000
#
#     Lenght     class
# 0       17  Negative
# 1       18  Negative
# 2        9  Positive
# 3       18  Negative
# 4        8  Positive
# 5       15  Positive
# 6       11  Negative
# 7       21  Negative
# 8       20   Neutral
# 9       19  Negative
# 10      24  Positive
# 11      19  Positive
# 12      16  Positive
# 13       8   Neutral
# 14      30  Positive
# 15      12   Neutral
# 16       8   Neutral
# 17      12   Neutral
# 18       8   Neutral
# 19      16   Neutral

# %%
def percentage(part,whole):
 return 100 * float(part)/float(whole)

noOfTweet = len(tweets)
positive = 0
negative = 0
neutral = 0
neutral_list = []
negative_list = []
positive_list = []
for tweet in tweets:
 score = SentimentIntensityAnalyzer().polarity_scores(tweet)
 neg = score["neg"]
 neu = score["neu"]
 pos = score["pos"]
 comp = score["compound"]
 
 if neg > pos:
  negative_list.append(tweet)
  negative += 1
 elif pos > neg:
  positive_list.append(tweet)
  positive += 1
 elif pos == neg:
  neutral_list.append(tweet)
  neutral += 1

positive = percentage(positive, noOfTweet)
negative = percentage(negative, noOfTweet)
neutral = percentage(neutral, noOfTweet)
positive = format(positive, ".1f")
negative = format(negative, ".1f")
neutral = format(neutral, ".1f")

# %%
neutral_list = pd.DataFrame(neutral_list)
negative_list = pd.DataFrame(negative_list)
positive_list = pd.DataFrame(positive_list)
print("total number: ",len(df["Tweets"]))
print("positive number: ",len(positive_list))
print("negative number: ", len(negative_list))
print("neutral number: ",len(neutral_list))
# Out:
# total number:  1000
# positive number:  146
# negative number:  821
# neutral number:  33

# %%
colors = sns.color_palette('pastel')[0:5]
plt.pie([len(positive_list),len(negative_list),len(neutral_list)], labels = ["Positive sentiments","Negative sentiments","Neutral sentiments"], colors = colors, autopct='%.0f%%')
plt.show()

# %%
sns.set_theme(style="ticks", color_codes=True)
sns.displot(data=df, x="Lenght",hue="class",col="class", palette="dark")

# %%
from wordcloud import WordCloud


# Generate a word cloud image
Tweets_String=str(df["Tweets"])

wordcloudimage = WordCloud(
                          max_words=100,
                          max_font_size=500,
                          font_step=2,
  
                          background_color='black',
                          width=1000,
                          height=720
                          ).generate(Tweets_String)
 
plt.figure(figsize=(15,7))
plt.axis("off")
plt.imshow(wordcloudimage)
wordcloudimage
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
df.columns
# Out:
# Index([0, 'Tweets', 'polarity', 'Subjectivity', 'Lenght', 'class'], dtype='object')

# %%
target=df["class"]
df2=df.copy()
del df2["Tweets"]
del df2["class"]

# %%
df2 = df2.loc[:, ['polarity', 'Subjectivity', 'Lenght']]

# %%
data_train, data_test, target_train, target_test = train_test_split(df2,target,test_size=0.3)
clf = RandomForestClassifier().fit(data_train,target_train)

# %%
target_pred = clf.predict(data_test)

# %%
clf.score(data_test,target_test)
# Out:
# 0.9966666666666667

# %%
# create the confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(target_test, target_pred)

print(cm)
# Out:
# [[ 68   0   0]
#  [  0 143   0]
#  [  0   1  88]]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   polarity      1000 non-null   float64
#  1   Subjectivity  1000 non-null   float64
#  2   Lenght        1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB

# %%
from sklearn.model_selection import KFold
df3=df2.to_numpy()
kf = KFold(n_splits=10)
kf.get_n_splits(df3)

print(kf)
for train_index, test_index in kf.split(df3):
    X_train, X_test = df3[train_index], df3[test_index]
    y_train, y_test = target[train_index], target[test_index]

clf3 = RandomForestClassifier().fit(X_train,y_train)
clf3.score(X_test,y_test)
# Out:
# KFold(n_splits=10, random_state=None, shuffle=False)
# 1.0
